# %%
#Realizado por Tomás Garzón Gómez 1001200959 Estudiante de Ingenieria de sistemas y computación.
import numpy as np
#El número cero hace referencia al elemento neutro.
matriz_1= np.array([(0,1, 2, 3, 4, 5),( 1,0, 3, 4, 5, 2),( 2, 3,0, 5, 1, 4),( 3, 4, 5,0, 2, 1),( 4, 5, 1, 2,0, 3),( 5, 2, 4, 1, 3,0)],dtype=object)

def total_elem(c):
    firstlist=c[0]
    total=0
    for i in firstlist:
        if i==0:
            total+=0
        else:
            total+=1
    return(total)

def totalcomb():
    num_comb=total_elem(matriz_1)**3
    return(num_comb)

def randomM(c):
    #ad=np.empty((0,totalcomb()),int)
    for ad in range(totalcomb()):
        b=np.random.choice(c[0],3,replace=True, p=[0.0, 0.20, 0.20, 0.20, 0.20, 0.20])
    #Escoger un arreglo de 3 elementos sin contar el elemento neutro.
        change_e=np.where(b!=0,b,1)#Asegurandose de que en caso de que en caso de que escoga el 0 se cambie por algo.
        print(change_e) 
        #ad = np.append(ad,np.array(change_e),axis=0)
    return(change_e)

#def lista_resul():
#    lst=[]
#    for x in randomM(matriz_1):
#        lst.append(x)
#    print(lst)

def asociatividad_1(a,b):
    for i in range(len(matriz_1)):
    #se usa un for para que primero recorra las filas de la lista de listas.
        if matriz_1[i][0]==matriz_1[a][0]:
            #se usa un if para que busque la fila que corresponde a el arreglo cualquiera que escogio la función randomM.
            for j in range(len(matriz_1[i])):
            #Se usa un for para que está vez apartir de que ya la fila ha sido escogida, ahora recorra las columnas en busca de la columna escogida.
                if matriz_1[i][j]==matriz_1[a][b]:
                    #print(matriz_1[i][0]) Se verifica que pertenezca a la fila correspondiente.
                    return(matriz_1[i][j])
                else:
                    j+=1
        else:
            i+=1

def asociatividad_2():
    #Tener en cuenta que existe asoc [0], asoc[1] y asoc[2]
    # Se llama la funcion randomM para saber la posición que quiere buscar en la matriz.
    asoc_2=asociatividad_1(asoc[0],asoc[1])
    print(matriz_1)
    print(asoc)
    print(asoc_2)
    a=asociatividad_1(asoc_2,asoc[2])
    print(a)
    return a

def asociatividad_3():
    #Tener en cuenta que existe asco [0], asoc[1] y asoc[2]
    # Se llama la funcion randomM para saber la posición que quiere buscar en la matriz.
    asoc_2=asociatividad_1(asoc[1],asoc[2])
    print(asoc) #Verificar que la operación se hace sobre las mismos espacios (números)
    print(asoc_2)
    a=asociatividad_1(asoc[0],asoc_2)
    print(a)
    return a

asoc=(randomM(matriz_1))

def verificar():
    a=asociatividad_2() #Se le asigna variables a el return de las funciones para poder compararlos.
    b=asociatividad_3()
    if a==b: #Comparando si el resultado de la operación es asociativa.
        print("Es probable que sea un grupo, debido a que su operación es asociativa.")
    else: #Significa que la operación no es un grupo.
        print("No es un grupo")


verificar()
#print(randomM(matriz_1))
#print(totalcomb())
#randomM(matriz_1)
#lista_resul()
